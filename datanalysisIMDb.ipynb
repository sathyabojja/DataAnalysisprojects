# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\sathy\Downloads\28th - Iris, movie analytics Project\28th -Seaborn movie analytics Project\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv")

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Film                         object
# Genre                        object
# Rotten Tomatoes Ratings %     int64
# Audience Ratings %            int64
# Budget (million $)            int64
# Year of release               int64
# dtype: object

# %%
#LIST OF MOST POPULAR GENRES

# %%
sns.countplot(x='Genre',data=df)
plt.title("List of Genres")
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %%
rating=df['Film'].value_counts(10).head(10)
sns.barplot(x=rating.values,y=rating.index,palette='magma')
plt.title('Highly Rated Movie')
plt.xlabel('Rating')
plt.ylabel('Film')
plt.show()
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_8420\3162662414.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rating.values,y=rating.index,palette='magma')

# %%
#HIGHLY AUDIENCE RATED MOVIES BASED ON GENRES

# %%
sns.barplot(x='Genre',y='Audience Ratings %',data=df,palette='magma')
plt.title('Highly rated movie based on genres')
plt.xlabel('Genre')
plt.ylabel('Audience Rating')
plt.show()
# Out:
# C:\Users\sathy\AppData\Local\Temp\ipykernel_8420\4187179775.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Genre',y='Audience Ratings %',data=df,palette='magma')
